# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
#from feature_engine.outliers import Winsorizer
#from scipy import stats
from sklearn.cluster import	KMeans
from sklearn.preprocessing import OneHotEncoder

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
mall_data=pd.read_csv("Mall_Customers.csv")

# %%
mall_data.columns=["custId","Gender","Age","Income","Spend"]

# %%
seg_data=mall_data.iloc[:,1:]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lc=LabelEncoder()
gender=lc.fit_transform(seg_data["Gender"])

# %%
seg_data.drop("Gender",axis=1,inplace=True)

# %%
seg_data["Gender"]=gender

# %%
TWSS = []
k = list(range(2, 9))

for i in k:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(seg_data)
    TWSS.append(kmeans.inertia_)
# Out:
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
TWSS
# Scree plot 
plt.plot(k, TWSS, 'ro-')
plt.xlabel("No_of_Clusters")
plt.ylabel("total_within_SS")

# Selecting 5 clusters from the above scree plot which is the optimum number of clusters 
model = KMeans(n_clusters = 3)
model.fit(seg_data)
# Out:
# C:\Users\eagle\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
model.labels_ # getting the labels of clusters assigned to each row 
mb = pd.Series(model.labels_)  # converting numpy array into pandas series object 
seg_data['clust'] = mb

# %%
centroids = model.cluster_centers_

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    x='Income',
    y='Spend',
    hue='clust',
    palette='tab10',
    data=seg_data,
    s=60
)

# Plot centroids
plt.scatter(
    centroids[:, 0],
    centroids[:, 1],
    s=200,
    marker='X'
)

plt.title("Customer Segmentation Using K-Means Clustering")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score")
plt.legend(title="Cluster")
plt.show()
