# %%
import numpy as np
import cv2 as cv

im = cv.imread('images//birds//169_bird-2295431_1280.jpg')
assert im is not None, "file could not be read, check with os.path.exists()"
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
#all contours
cv.drawContours(im, contours, -1, (0,255,0), 3)


cv.imshow("image",im)
k = cv.waitKey(0)

# %%
im = cv.imread('images//birds//169_bird-2295431_1280.jpg')
assert im is not None, "file could not be read, check with os.path.exists()"
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# all contours
#cv.drawContours(im, contours, -1, (0,255,0), 3)

cnt = contours[2]
cv.drawContours(im, [cnt], 0, (0,255,0), 3)
cv.imshow("image",im)
k = cv.waitKey(0)

# %% [markdown]
# # canny edge detection

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('images//birds//169_bird-2295431_1280.jpg',
                cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
edges = cv.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('images//birds//153_barn-owl-1107397_1280.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.imshow(img)
plt.show()
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('images//birds//127_bird-341898_1280.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.imshow(img);plt.show()
plt.hist(img.ravel(),256,[0,256]); plt.show()
